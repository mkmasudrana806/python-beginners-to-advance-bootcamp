# %% [markdown]
# # Banking System Using OOP (ATM Banking System)
# Use pascal case while writting a class name. use 'class' keyword before the class name
#
# # Class Diagram of the ATM Machine
# Structure:
# class name
#
# data property
#
# methods
#
# `Example:`
#
# -------------
#
# ATM Machine
#
# ------------
#
# pin
#
# balance
#
# ------------
# -> create_pin
#
# -> deposit
#
# -> withdraw
#
# -> check balance
#
# -> change pin
#
# -----------

# %%
# ------------- ATM Machine class -------------
class AtmMachine:
  # constructor function. all the data property need to write inside constructor
  # self define it is AtmMachine class
  def __init__(self) -> None:
    self.pin = ""
    self.balance = 0
    self.menu()

  # menu method of this class
  def menu(self):
    user_input = input("""
    Hello, How would you like to proceed?
    1. Enter 1 to create pin
    2. Enter 2 to deposit
    3. Enter 3 to withdraw
    4. Enter 4 to check balance
    5. Enter 5 to change pin
    """)
    if user_input == "1":
      # create a pin
      self.create_pin()

    elif user_input == "2":
      # deposit
      self.deposit()

    elif user_input == "3":
      # withdraw
      self.withdraw()

    elif user_input == "4":
      # check balance
      self.check_balance()

    elif user_input == "5":
      # change pin
      self.change_pin()

    else:
      print("Invalid input")

  # create pin method
  def create_pin(self):
    self.pin = input("Enter your pin: ")
    print("Pin set successfully")

    self.balance = int(input("Enter your balance: "))
    print("Balance set successfully")

    print("Pin created successfully")
    self.menu()


  # change pin method
  def change_pin(self):
    old_pin = input("Enter old pin: ")

    if old_pin == self.pin:
      new_pin = input("Enter new pin: ")
      self.pin = new_pin
      print("Pin changed successfully")
    else:
      print("Invalid pin")
    self.menu()



  # deposit method
  def deposit(self):
    user_pin = input("Enter pin: ")
    if user_pin == self.pin:
      amount = int(input("Enter amount: "))
      self.balance = self.balance + amount
      print("Deposit successfully")
    else:
      print("Invalid pin")
    self.menu()


  # withdraw method
  def withdraw(self):
    user_pin = input("Enter your pin: ")
    if user_pin == self.pin:
      amount = int(input("Enter amount: "))
      if amount <= self.balance:
        self.balance = self.balance - amount
        print("Withdraw successfully")
      else:
        print("Insufficient balance")
    else:
      print("Invalid pin")
    self.menu()


  # check balance method
  def check_balance(self):
    user_pin = input("Enter your pin: ")
    if user_pin == self.pin:
      print("Your balance is: ", self.balance)
    else:
      print("Invalid pin")
    self.menu()




# ------------- ATM Machine for ICIC Bank -------------
class AtmMachineICIC:
  # constructor function. all the data property need to write inside constructor
  # self define it is AtmMachine class
  def __init__(self) -> None:
    self.pin = ""
    self.balance = 0
    self.menu()

  # menu method of this class
  def menu(self):
    user_input = input("""
    Hello, How would you like to proceed?
    1. Enter 1 to create pin
    2. Enter 2 to deposit
    3. Enter 3 to withdraw
    4. Enter 4 to check balance
    5. Enter 5 to change pin
    """)
    if user_input == "1":
      # create a pin
      self.create_pin()

    elif user_input == "2":
      # deposit
      self.deposit()

    elif user_input == "3":
      # withdraw
      self.withdraw()

    elif user_input == "4":
      # check balance
      self.check_balance()

    elif user_input == "5":
      # change pin
      self.change_pin()

    else:
      print("Invalid input")

  # create pin method
  def create_pin(self):
    self.pin = input("Enter your pin: ")
    print("Pin set successfully")

    self.balance = int(input("Enter your balance: "))
    print("Balance set successfully")

    print("Pin created successfully")
    self.menu()


  # change pin method
  def change_pin(self):
    old_pin = input("Enter old pin: ")

    if old_pin == self.pin:
      new_pin = input("Enter new pin: ")
      self.pin = new_pin
      print("Pin changed successfully")
    else:
      print("Invalid pin")
    self.menu()



  # deposit method
  def deposit(self):
    user_pin = input("Enter pin: ")
    if user_pin == self.pin:
      amount = int(input("Enter amount: "))
      self.balance = self.balance + amount
      print("Deposit successfully")
    else:
      print("Invalid pin")
    self.menu()


  # withdraw method
  def withdraw(self):
    user_pin = input("Enter your pin: ")
    if user_pin == self.pin:
      amount = int(input("Enter amount: "))
      if amount <= self.balance:
        self.balance = self.balance - amount
        print("Withdraw successfully")
      else:
        print("Insufficient balance")
    else:
      print("Invalid pin")
    self.menu()


  # check balance method
  def check_balance(self):
    user_pin = input("Enter your pin: ")
    if user_pin == self.pin:
      print("Your balance is: ", self.balance)
    else:
      print("Invalid pin")
    self.menu()

# %%
# ------------ object create of AtmMacine class ------------
# whenever we create any object of a class. the constructor function is called automatically
# here when we have created 'obj' object using AtmMachine() constructor. it called automatically
obj = AtmMachine()
obj.balance
type(obj) # AtmMachine class type

obj.create_pin()

# %%
# ----------- ATM Machine ICIC Bank -----------
obj = AtmMachineICIC()
# Out:
#     Hello, How would you like to proceed?
#     1. Enter 1 to create pin
#     2. Enter 2 to deposit
#     3. Enter 3 to withdraw
#     4. Enter 4 to check balance
#     5. Enter 5 to change pin
#     1
# Enter your pin: 123
# Pin set successfully
# Enter your balance: 2398423984
# Balance set successfully
# Pin created successfully
#
#     Hello, How would you like to proceed?
#     1. Enter 1 to create pin
#     2. Enter 2 to deposit
#     3. Enter 3 to withdraw
#     4. Enter 4 to check balance
#     5. Enter 5 to change pin
#     4
# Enter your pin: 123
# Your balance is:  2398423984
#
#     Hello, How would you like to proceed?
#     1. Enter 1 to create pin
#     2. Enter 2 to deposit
#     3. Enter 3 to withdraw
#     4. Enter 4 to check balance
#     5. Enter 5 to change pin
#     5
# Enter old pin: 123
# Enter new pin: 234
# Pin changed successfully
# ---------------------------------------------------------------------------
# ...

# %% [markdown]
# # Functions vs Methods
# Whatever functions we write in a class using self keywords is called methods.
#
# whatever functions we wrtie outside of a class is called function
#
# **Simple Trick**: function inside class is called methods. outside of a class is called function
